# %%
import pandas as pd
data = pd.read_csv('C:\\Users\\raja.a.muthuraman\\Downloads\\DS\\Multiple Regression\\Restaurant_Profit_Data.csv')
data
# Out:
#     Miscellaneous_Expenses  Food_Innovation_Spend  Advertising     City  \
# 0                138671.80              167497.20    475918.10  Chicago
# 1                153151.59              164745.70    448032.53   Mumbai
# 2                102919.55              155589.51    412068.54    Tokyo
# 3                120445.85              146520.41    387333.62  Chicago
# 4                 93165.77              144255.34    370302.42    Tokyo
# 5                101588.71              134024.90    366995.36  Chicago
# 6                148972.87              136763.46    131850.82   Mumbai
# 7                147304.06              132446.13    328010.68    Tokyo
# 8                150492.95              122690.52    315747.29  Chicago
# 9                110453.17              125482.88    309115.62   Mumbai
# 10               112368.11              104061.08    233294.95    Tokyo
# 11                93564.61              102819.96    253878.55   Mumbai
# ...

# %%
data.shape
# Out:
# (50, 5)

# %%
ohe=pd.get_dummies(X[:,3])
ohe
data = pd.concat([data.reset_index(drop=True),ohe],axis=1)
data
data = data.drop('City',axis=1)
data
# Out:
#     Miscellaneous_Expenses  Food_Innovation_Spend  Advertising     Profit  0  \
# 0                138671.80              167497.20    475918.10  202443.83  1
# 1                153151.59              164745.70    448032.53  201974.06  0
# 2                102919.55              155589.51    412068.54  201232.39  0
# 3                120445.85              146520.41    387333.62  193083.99  1
# 4                 93165.77              144255.34    370302.42  176369.94  0
# 5                101588.71              134024.90    366995.36  167173.12  1
# 6                148972.87              136763.46    131850.82  166304.51  0
# 7                147304.06              132446.13    328010.68  165934.60  0
# 8                150492.95              122690.52    315747.29  162393.77  1
# 9                110453.17              125482.88    309115.62  159941.96  0
# 10               112368.11              104061.08    233294.95  156303.95  0
# ...

# %%
features = ["Miscellaneous_Expenses","Food_Innovation_Spend","Advertising",0,1,2]
response = ["Profit"]
# X is independent variables
# Y is dependent variable
X=data[features].values
y=data[response].values
X
# Out:
# array([[1.3867180e+05, 1.6749720e+05, 4.7591810e+05, 1.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [1.5315159e+05, 1.6474570e+05, 4.4803253e+05, 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0291955e+05, 1.5558951e+05, 4.1206854e+05, 0.0000000e+00,
#         0.0000000e+00, 1.0000000e+00],
#        [1.2044585e+05, 1.4652041e+05, 3.8733362e+05, 1.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [9.3165770e+04, 1.4425534e+05, 3.7030242e+05, 0.0000000e+00,
#         0.0000000e+00, 1.0000000e+00],
#        [1.0158871e+05, 1.3402490e+05, 3.6699536e+05, 1.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [1.4897287e+05, 1.3676346e+05, 1.3185082e+05, 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.4730406e+05, 1.3244613e+05, 3.2801068e+05, 0.0000000e+00,
#         0.0000000e+00, 1.0000000e+00],
#        [1.5049295e+05, 1.2269052e+05, 3.1574729e+05, 1.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
# ...

# %%
X = X[:,1:]
X
# Out:
# array([[1.6749720e+05, 4.7591810e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [1.6474570e+05, 4.4803253e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [1.5558951e+05, 4.1206854e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [1.4652041e+05, 3.8733362e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [1.4425534e+05, 3.7030242e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [1.3402490e+05, 3.6699536e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [1.3676346e+05, 1.3185082e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
#        [1.3244613e+05, 3.2801068e+05, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [1.2269052e+05, 3.1574729e+05, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00],
#        [1.2548288e+05, 3.0911562e+05, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00],
# ...

# %%
#Dividing data in test and train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

#Importing neccesary packages
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
#using sklearn method
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(X_train,y_train)
print(reg.coef_)
print(reg.intercept_)
# Out:
# [[ 8.01400884e-01  2.86044604e-02 -4.24252960e+01 -3.62642655e+02
#    4.05067951e+02]]
# [54493.27600164]

# %%
import statsmodels.api as sm
X_with_constant = sm.add_constant(X_train)
model = sm.OLS(y_train, X_with_constant)
results = model.fit()
results.params
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     146.5
# Date:                Sat, 03 Sep 2022   Prob (F-statistic):           3.14e-19
# Time:                        12:27:08   Log-Likelihood:                -370.20
# No. Observations:                  35   AIC:                             750.4
# Df Residuals:                      30   BIC:                             758.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.087e+04   2643.283     15.462      0.000    3.55e+04    4.63e+04
# ...

# %%
# Training score
y_pred = reg.predict(X_train)
df = pd.DataFrame(data = y_train ,columns =['y_test'])
df['y_pred'] = y_pred
df
# Out:
#        y_test         y_pred
# 0   165934.60  170423.358123
# 1   142784.65  160198.036117
# 2    75108.08   57146.556740
# 3    45855.41   56724.909993
# 4   111186.64  111931.435857
# 5   140099.04  155557.800740
# 6   110119.59  109027.194909
# 7   107609.84  108104.453448
# 8   137174.93  126051.545009
# 9    81680.49   79149.647378
# 10  128656.03  125623.340105
# 11   79940.98   69733.252131
# 12  162393.77  161806.922745
# 13  144489.35  136920.419937
# 14  117586.34  111738.995342
# 15  167173.12  172356.228286
# 16  135552.37  140231.728006
# 17   88421.91   83956.765668
# 18   24863.40   57262.444292
# 19  201974.06  198973.711725
# 20  151767.52  139107.018484
# 21  100131.14   96923.910417
# 22  118734.04  122054.714949
# 23  166304.51  167504.512643
# 24  118915.99  119576.378203
# 25  100890.19   85462.290654
# 26  121495.02  127685.724642
# 27  132958.86  125547.334613
# 28  159941.96  163534.809816
# 29   91187.76   91876.877833
# 30   59672.75   66291.013510
# ...

# %%
# Test score
from sklearn.metrics import mean_squared_error,r2_score
print('MSE: %.2f' % mean_squared_error(y_train, y_pred))
print('R^2: %.2f' % r2_score(y_train, y_pred))
# Out:
# MSE: 90102423.54
# R^2: 0.95

# %%
y_predict = reg.predict(X_test)

# %%
df = pd.DataFrame(data = y_test ,columns =['y_test'])
df['y_predict'] = y_predict
df
# Out:
#        y_test      y_predict
# 0   113464.38  113051.315915
# 1   154441.40  143792.699113
# 2   156303.95  144966.261612
# 3    87980.83   83796.010549
# 4   201232.39  191374.913042
# 5   115190.31  124180.237338
# 6    91411.06   77801.930172
# 7   107665.56  107808.694485
# 8   120534.25  124713.593449
# 9   176369.94  181097.001859
# 10  106960.92  107350.417402
# 11  106661.51   99044.908145
# 12  115915.54  120941.056816
# 13  106894.80   99205.940430
# 14  134448.90  138701.876983

# %%
# Test score
from sklearn.metrics import mean_squared_error,r2_score
print('MSE: %.2f' % mean_squared_error(y_test, y_predict))
print('R^2: %.2f' % r2_score(y_test, y_predict))
# Out:
# MSE: 54885162.90
# R^2: 0.94

# %%
some = [1,0,160349,134321,401400]
import numpy as np
feature_array = np.array(some)
feature_array = feature_array.reshape(1,-1)
print(feature_array)
reg.predict(feature_array)
# Out:
# [[       0        0 15000000   134321   401400]]
# array([[-5.22441195e+08]])

# %%
round(float(reg.predict(feature_array)),2)
# Out:
# -522441195.17

# %%
x = [100000,50000,50,200000]
x1 = np.log(x)
x1
# Out:
# array([11.51292546, 10.81977828,  3.91202301, 12.20607265])

# %%
x2 = np.exp(x1)
x2
# Out:
# array([1.e+05, 5.e+04, 5.e+01, 2.e+05])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\RAJAA~1.MUT\AppData\Local\Temp/ipykernel_23392/3679850073.py in <module>
# ----> 1 round(float(x2),2)
#
# TypeError: only size-1 arrays can be converted to Python scalars
